# %% [markdown]
# <a href="https://colab.research.google.com/github/Hugh-Carlson/CSC576DataMining/blob/main/CSC576DataPreprocessingLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Preprocessing involves transforming raw data into a clean and structured format suitable for modeling.
# Raw data often contains noise, missing values, inconsistencies, or irrelevant features which can negatively impact model performance
# Data preprocessing enhances quality of the data, making it more reliable and suitable for analysis

# %%
import pandas as pd
# Creation of sample data
data1 = {
    "ID": [1,2,3,4,4,5,6,6],
    "Name": ['Alicew','Bob','Charlie','David','David','Eve','Frank','Frank'],
    "Age": [25,30,35,40,40,28,50,50]
}

df1 = pd.DataFrame(data1)
df1
# Out:
#    ID     Name  Age
# 0   1   Alicew   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 3   4    David   40
# 4   4    David   40
# 5   5      Eve   28
# 6   6    Frank   50
# 7   6    Frank   50

# %%
# Remove duplicate and keep the first occurence

df_noduplicate = df1.drop_duplicates(keep='first')
df_noduplicate
# Out:
#    ID     Name  Age
# 0   1   Alicew   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 3   4    David   40
# 5   5      Eve   28
# 6   6    Frank   50

# %%
import pandas as pd
# Creation of sample data

data2 = {
    "Name": ['Alice','Bob','Charlie','David','Eve'],
    "Age": [25,30,None,40,28],
    "Salary": [50000,60000,55000,None,58000]
}

df2 = pd.DataFrame(data2)
df2
# Out:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  30.0  60000.0
# 2  Charlie   NaN  55000.0
# 3    David  40.0      NaN
# 4      Eve  28.0  58000.0

# %%
# Deleting Rows with Missing values
df2_no_missing = df2.dropna()
print("Dataset after removing rows with missing values:")
df2_no_missing
# Out:
# Dataset after removing rows with missing values:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 1    Bob  30.0  60000.0
# 4    Eve  28.0  58000.0

# %%
# Deleting Columns with Missing values

df2_deleted_columns = df2.dropna(axis=1)
print("\nDataset after deleting columns with missing values:")
df2_deleted_columns
# Out:
# Dataset after deleting columns with missing values:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eve

# %%
df2.fillna(0, inplace=True)
df2
# Out:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  30.0  60000.0
# 2  Charlie   0.0  55000.0
# 3    David  40.0      0.0
# 4      Eve  28.0  58000.0

# %%
# Fill with mean, median, or mode

mean_age = df2['Age'].mean()
mean_salary = df2['Salary'].mean()

print("\nMean Age:", mean_age)
print("\nMean Salary:", mean_salary)
# Out:
# Mean Age: 24.6
#
# Mean Salary: 44600.0

# %%
import pandas as pd
# Creation of sample data

data2 = {
    "Name": ['Alice','Bob','Charlie','David','Eve'],
    "Age": [25,30,None,40,28],
    "Salary": [50000,60000,55000,None,58000]
}

df=pd.DataFrame(data2)
df
# Out:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  30.0  60000.0
# 2  Charlie   NaN  55000.0
# 3    David  40.0      NaN
# 4      Eve  28.0  58000.0

# %%
# Fill with mean, median, or mode

mean_age = df['Age'].mean()
mean_salary = df['Salary'].mean()

print("\nMean Age:", mean_age)
print("\nMean Salary:", mean_salary)
# Out:
# Mean Age: 30.75
#
# Mean Salary: 55750.0

# %%
# Filling Missing values with the Mean
df_mean = df.copy()

df_mean = df_mean.assign(
    Age=df_mean["Age"].fillna(df_mean["Age"].mean()),
    Salary=df_mean["Salary"].fillna(df_mean["Salary"].mean())
)


print("New data frame")
df_mean
# Out:
# New data frame
#       Name    Age   Salary
# 0    Alice  25.00  50000.0
# 1      Bob  30.00  60000.0
# 2  Charlie  30.75  55000.0
# 3    David  40.00  55750.0
# 4      Eve  28.00  58000.0

# %%
# Median

median_age = df['Age'].median()
median_salary = df['Salary'].median()

print("\nMedian Age:", median_age)
print("\nMedian Salary:", median_salary)
# Out:
# Median Age: 29.0
#
# Median Salary: 56500.0

# %%
import pandas as pd
# Creating a dataset with misssing values

data = {
    "Name": ['Alice','Bob','Charlie','David','Eve'],
    "Age": [25,30,None,40,28], # Missing age for Charlie
    "Salary": [50000,60000,55000,None,58000], # Missing salary for David
    "City": ['New York','Los Angeles',None,'Chicago','Houston'] # Missing city for Charlie
}

df=pd.DataFrame(data)
print("\nOriginal Dataset:\n")
df
# Out:
# Original Dataset:
#       Name   Age   Salary         City
# 0    Alice  25.0  50000.0     New York
# 1      Bob  30.0  60000.0  Los Angeles
# 2  Charlie   NaN  55000.0         None
# 3    David  40.0      NaN      Chicago
# 4      Eve  28.0  58000.0      Houston

# %%
# Creating a copy of the dataset for median imputation

df_median = df.copy()

# Applying Median Imputation
df_median['Age'] = df_median['Age'].fillna(df_median['Age'].median())
df_median['Salary'] = df_median['Salary'].fillna(df_median['Salary'].median())

# Applying Mode Imputation for Categorical Column (City)
df_median['City'] = df_median['City'].fillna(df_median['City'].mode()[0])

print("\nDataset after Median and Mode Imputation:\n")
df_median
# Out:
# Dataset after Median and Mode Imputation:
#       Name   Age   Salary         City
# 0    Alice  25.0  50000.0     New York
# 1      Bob  30.0  60000.0  Los Angeles
# 2  Charlie  29.0  55000.0      Chicago
# 3    David  40.0  56500.0      Chicago
# 4      Eve  28.0  58000.0      Houston

# %%
# Mode

import pandas as pd
# Creating a dataset with misssing values

data = {
    "Name": ['Alice','Bob','Charlie','David','Eve'],
    "Age": [25,30,None,40,28], # Missing age for Charlie
    "Salary": [50000,60000,55000,None,58000], # Missing salary for David
    "City": ['New York','Los Angeles',None,'Chicago','Houston'] # Missing city for Charlie
}

df=pd.DataFrame(data)
print("\nOriginal Dataset:\n")
df
# Out:
# Original Dataset:
#       Name   Age   Salary         City
# 0    Alice  25.0  50000.0     New York
# 1      Bob  30.0  60000.0  Los Angeles
# 2  Charlie   NaN  55000.0         None
# 3    David  40.0      NaN      Chicago
# 4      Eve  28.0  58000.0      Houston

# %%
# Filling missing values with mode

df_mode = df.copy()

# Assesing Mode values explicitly
df_mode['Age'] = df_mode['Age'].fillna(df_mode['Age'].mode()[0])
df_mode['Salary'] = df_mode['Salary'].fillna(df_mode['Salary'].mode()[0])
df_mode['City'] = df_mode['City'].fillna(df_mode['City'].mode()[0]) # Mode for City

print("\nDataset after Mode Imputation:\n")
df_mode
# Out:
# Dataset after Mode Imputation:
#       Name   Age   Salary         City
# 0    Alice  25.0  50000.0     New York
# 1      Bob  30.0  60000.0  Los Angeles
# 2  Charlie  25.0  55000.0      Chicago
# 3    David  40.0  50000.0      Chicago
# 4      Eve  28.0  58000.0      Houston

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Generate sample data ( 10 Data Points, 2 features)
data = np.array([[10,200],
                 [20,250],
                 [30,300],
                 [40,350],
                 [50,400],
                 [60,450],
                 [70,500],
                 [80,550],
                 [90,600],
                 [100,650]])

df = pd.DataFrame(data, columns=['Feature1','Feature2'])

# Display Original Data
print("Original Data:")
df
# Out:
# Original Data:
#    Feature1  Feature2
# 0        10       200
# 1        20       250
# 2        30       300
# 3        40       350
# 4        50       400
# 5        60       450
# 6        70       500
# 7        80       550
# 8        90       600
# 9       100       650

# %%
# Normalization (Min-Max Scaling)
scaler_minmax = MinMaxScaler()

normalized_data = scaler_minmax.fit_transform(df)

# Convert normalized data to DataFrame for better visualization
df_normalized = pd.DataFrame(normalized_data, columns=["Feature1", "Feature2"])

# Display Normalized data
print("\nNormalized Data (Min-Max Scaling):")
df_normalized
# Out:
# Normalized Data (Min-Max Scaling):
#    Feature1  Feature2
# 0  0.000000  0.000000
# 1  0.111111  0.111111
# 2  0.222222  0.222222
# 3  0.333333  0.333333
# 4  0.444444  0.444444
# 5  0.555556  0.555556
# 6  0.666667  0.666667
# 7  0.777778  0.777778
# 8  0.888889  0.888889
# 9  1.000000  1.000000

# %%
# Standardization (Z-Score Scaling)
scaler_standard = StandardScaler()
standardized_data = scaler_standard.fit_transform(df)

# Convert standardized data to DataFrame for better visualization
df_standardized = pd.DataFrame(standardized_data, columns=["Feature1", "Feature2"])

# Display Standardized data
print("\nStandardized Data (Z-Score Scaling):")
df_standardized
# Out:
# Standardized Data (Z-Score Scaling):
#    Feature1  Feature2
# 0 -1.566699 -1.566699
# 1 -1.218544 -1.218544
# 2 -0.870388 -0.870388
# 3 -0.522233 -0.522233
# 4 -0.174078 -0.174078
# 5  0.174078  0.174078
# 6  0.522233  0.522233
# 7  0.870388  0.870388
# 8  1.218544  1.218544
# 9  1.566699  1.566699

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data with outliers
data = np.array([10,12,12,13,14,15,16,17,18,100])

# Create a boxplot
figure=plt.figure(figsize=(5,3))
plt.boxplot(data)
plt.title("Boxplot for Outlier Detection")
plt.grid=(True)
plt.show()

# %%
import numpy as np
from scipy import stats

# Generate sample data with outliers
data = np.array([10,12,12,13,14,15,16,17,18,100])

# Calculate the Z-Scores
z_scores = stats.zscore(data)

# Define the threshold for identifying outliers (commonly 2.5 or 3)
threshold = 2.5 # Adjusted threshold to catch more subtle outliers

# Identify outliers
outliers = np.where(np.abs(z_scores) > threshold)

print("Z-Scores:", z_scores)
print("")
print("Outlier Indices:", outliers)
print("")
print("Outlier values:", data[outliers])
# Out:
# Z-Scores: [-0.49085998 -0.41355919 -0.41355919 -0.3749088  -0.33625841 -0.29760802
#  -0.25895763 -0.22030723 -0.18165684  2.9876753 ]
#
# Outlier Indices: (array([9]),)
#
# Outlier values: [100]

# %%
from sklearn.preprocessing import LabelEncoder

# Sample Data
data = ['Red','Green','Blue','Red','Green']

# Initialize label encoder
label_encoder = LabelEncoder()

# Fit and transform the data
encoded_data = label_encoder.fit_transform(data)

# Display the encoded data
print("Label the Encoded Data:", encoded_data)
# Out:
# Label the Encoded Data: [2 1 0 2 1]

# %%
import pandas as pd

# Sample Data
data = ['Red','Green','Blue','Red','Green']

# Create a DataFrame
df = pd.DataFrame(data,columns=['Color'])

# Apply one hot encoding with dtype=int to get 0 and 1
one_hot_encoded = pd.get_dummies(df['Color'], dtype=int)

# Display the One-Hot encoded data
print("One-Hot Encoded Data:")
print(one_hot_encoded)
# Out:
# One-Hot Encoded Data:
#    Blue  Green  Red
# 0     0      0    1
# 1     0      1    0
# 2     1      0    0
# 3     0      0    1
# 4     0      1    0
